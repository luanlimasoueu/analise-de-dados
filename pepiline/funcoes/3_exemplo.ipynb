# %%
import pandas as pd

data = pd.read_csv("Mall_Customers.csv")
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# filtering by Gender and Annual Income
def filter_male_income(dataframe, col1,col2):
    return data[(dataframe[col1] == "Male") & (dataframe[col2] >= 15) ]

# groupby mean and dropping ID columns
def mean_group(dataframe, col):
    return dataframe.groupby(col).mean().drop("CustomerID",axis=1)

# changing column names to uppercase
def uppercase_column_name(dataframe):
    dataframe.columns = dataframe.columns.str.upper()
    return dataframe 

# plot bar chart using pandas
def bar_plot(dataframe, col):
    return dataframe.plot(kind="bar", y=col, figsize=(15,10))

# %%
data.pipe(filter_male_income, col1="Gender", col2="Annual Income (k$)")
# Out:
#      CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1   Male   19                  15                      39
# 1             2   Male   21                  15                      81
# 8             9   Male   64                  19                       3
# 10           11   Male   67                  19                      14
# 14           15   Male   37                  20                      13
# ..          ...    ...  ...                 ...                     ...
# 187         188   Male   28                 101                      68
# 192         193   Male   33                 113                       8
# 197         198   Male   32                 126                      74
# 198         199   Male   32                 137                      18
# 199         200   Male   30                 137                      83
#
# [88 rows x 5 columns]

# %%
data.pipe(filter_male_income, col1="Gender", col2="Annual Income (k$)").pipe(
                mean_group, "Age"
                ).pipe(uppercase_column_name)
# Out:
# C:\Users\Luan Lima\AppData\Local\Temp\ipykernel_4072\43438034.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return dataframe.groupby(col).mean().drop("CustomerID",axis=1)
#      ANNUAL INCOME (K$)  SPENDING SCORE (1-100)
# Age
# 18            46.666667               64.000000
# 19            54.666667               35.666667
# 20            51.666667               40.000000
# 21            15.000000               81.000000
# 22            20.000000               79.000000
# 24            49.000000               72.000000
# 25            50.500000               42.500000
# 26            58.000000               54.500000
# 27            77.500000               62.500000
# 28            88.333333               80.000000
# 29            28.000000               82.000000
# 30           118.000000               90.000000
# 31            25.000000               73.000000
# 32            99.600000               64.200000
# 33            77.500000               34.000000
# 34            78.000000               45.500000
# 35            48.333333               62.000000
# 36            87.000000               51.000000
# 37            49.000000                7.000000
# 38            62.500000               65.000000
# 39            72.666667               84.666667
# 40            70.666667               52.000000
# 42            86.000000               20.000000
# 43            74.500000               26.000000
# 46            98.000000               15.000000
# 47            57.000000               25.000000
# 48            58.200000               41.800000
# 49            62.000000               56.000000
# 50            85.000000               26.000000
# 52            23.000000               29.000000
# 53            39.500000               25.000000
# 54            63.000000               46.000000
# 57            54.000000               51.000000
# 58            88.000000               15.000000
# 59            65.250000               33.000000
# 60            30.000000                4.000000
# 63            48.000000               51.000000
# 64            19.000000                3.000000
# 65            63.000000               52.000000
# 66            63.000000               48.000000
# 67            45.000000               38.000000
# 68            63.000000               43.000000
# 69            44.000000               46.000000
# 70            47.500000               55.500000

# %%
data.pipe(filter_male_income, col1="Gender", col2="Annual Income (k$)").pipe(
                mean_group, "Age"
                ).pipe(uppercase_column_name).pipe(bar_plot,"ANNUAL INCOME (K$)")
# Out:
# C:\Users\Luan Lima\AppData\Local\Temp\ipykernel_4072\43438034.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return dataframe.groupby(col).mean().drop("CustomerID",axis=1)
# <Axes: xlabel='Age'>
