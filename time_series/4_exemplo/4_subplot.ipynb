# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf

# %%
indicadores = pd.read_csv('bcdata.sgs.24363.csv', sep = ';')

# %%
# Plotar o gráfico
plt.figure(figsize=(10, 6))
sns.lineplot(data=indicadores, x="data", y="valor")
plt.title("Índice de Atividade Econômica do Banco Central - IBC-Br (2004-2022)")
plt.xticks(rotation=90)
plt.xlabel("Mês")
plt.ylabel("Valor")
plt.grid(True)
plt.xticks(range(0, len(indicadores["data"]), 6))
plt.show()

# %%
range(0, len(indicadores["data"]), 6)
# Out:
# range(0, 253, 6)

# %%
253/6
# Out:
# 42.166666666666664

# %%
# Plotar o gráfico
plt.figure(figsize=(10, 6))
sns.lineplot(data=indicadores, x="data", y="valor")
plt.title("Índice de Atividade Econômica do Banco Central - IBC-Br (2004-2022)")
plt.xticks(rotation=90)
plt.xlabel("Mês")
plt.ylabel("Valor")
plt.grid(True)
plt.xticks(range(0, len(indicadores["data"]), 6))
plt.yticks(range(0, len(indicadores["valor"]), 10))
plt.show()
