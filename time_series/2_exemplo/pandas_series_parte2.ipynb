# %%
import pandas as pd

# %%
pd.to_datetime(['01/01/2019','01/02/2019','01/03/2019' ])
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['01/01/2019','02/01/2019','03/01/2019' ], format='%d/%m/%Y')
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03'], dtype='datetime64[ns]', freq=None)

# %%
dia = pd.Timestamp('2018-01-05')

# %%
dia.day_name()
# Out:
# 'Friday'

# %%
dia2 = dia + pd.Timedelta('1 day')

# %%
dia2
# Out:
# Timestamp('2018-01-06 00:00:00')

# %%
dia + pd.offsets.BDay(1)
# Out:
# Timestamp('2018-01-08 00:00:00')

# %%
pd.date_range('2019', freq='D', periods=365)
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
index = pd.date_range('2019', freq='D', periods=365)

# %%
import numpy as np

# %%
values = np.random.normal(10, 2, 365)

# %%
ts = pd.Series(values, index=index )
ts.plot()
# Out:
# <Axes: >

# %%
index = pd.date_range('2019', freq='H', periods=365)
ts = pd.Series(values, index=index )
ts.plot()
# Out:
# <Axes: >

# %%
ts.resample('2H').sum()
# Out:
# 2019-01-01 00:00:00    16.637177
# 2019-01-01 02:00:00    18.779310
# 2019-01-01 04:00:00    19.186920
# 2019-01-01 06:00:00    22.531537
# 2019-01-01 08:00:00    18.310890
#                          ...
# 2019-01-15 20:00:00    18.007981
# 2019-01-15 22:00:00    20.399061
# 2019-01-16 00:00:00    22.665673
# 2019-01-16 02:00:00    25.151053
# 2019-01-16 04:00:00     8.078561
# Freq: 2H, Length: 183, dtype: float64

# %%
ts.resample('2H').interpolate()
# Out:
# 2019-01-01 00:00:00     9.220575
# 2019-01-01 02:00:00     8.206219
# 2019-01-01 04:00:00     7.704128
# 2019-01-01 06:00:00     8.687369
# 2019-01-01 08:00:00     9.558727
#                          ...
# 2019-01-15 20:00:00     7.775755
# 2019-01-15 22:00:00    10.845242
# 2019-01-16 00:00:00     7.263426
# 2019-01-16 02:00:00    12.321021
# 2019-01-16 04:00:00     8.078561
# Freq: 2H, Length: 183, dtype: float64
