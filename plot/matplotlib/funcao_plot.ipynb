# %%
import math
import matplotlib.pyplot as plt


base1 = [2, 4, 5, 6, 7]
base2 = [4, 90, 8, 6, 8]
base3 = [4, 7, 8, 6, 8]
base4 = [4, 7, -50, 6, 8]
base5 = [1, 2, 90, 5, 90]
base6 = [1, 2, 90, 1, 1]

base_final = [ base1, base2, base3, base4, base5, base6] 

def input_informacoes(base, linhas):

    colunas = (len(base)/linhas)
    colunas = math.ceil(colunas)

    figure, axis = plt.subplots(colunas, linhas) 

    ref_base = 0
    for i in range(len(base)-2):
        for j in range(colunas-1):
            print(i, j)
            print(ref_base)
            
            if ref_base <= len(base)-1: 
                axis[i, j].plot([2, 4, 5, 6, 7], base[ref_base] ) 
                ref_base =  ref_base +1


    '''figure, axis = plt.subplots(colunas, linhas)'''

    ''''ref = 0
    for i in range(len(base)-1):
        for j in range(colunas):
            if ref<= len(base_final):
                axis[i, j].plot([2, 4, 5, 6, 7], base_final[ref] ) 
                ref = ref + 1
    
    plt.show() '''

input_informacoes(base_final, 2)
# Out:
# 0 0
# 0
# 0 1
# 1
# 1 0
# 2
# 1 1
# 3
# 2 0
# 4
# 2 1
# 5
# 3 0
# 6
# 3 1
# 6
